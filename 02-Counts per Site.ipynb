# %%
from math import pi as PI
import pandas as pd
df = pd.read_csv('data.csv', dtype=str)

# %%
tuple(df.columns.values)
# Out:
# ('Unnamed: 0',
#  'Bird Species',
#  'Coordinates',
#  'Date',
#  'Distance Bin',
#  'Group Name',
#  'Habitat Type',
#  'Location',
#  'Remarks',
#  'Time',
#  'Time Period')

# %% [markdown]
# # Simplify data
# by removing useless columns
# - `Unnamed: 0` is a side effect column from preprocess
# - `Coordinates` is too varied in formatting and accuracy to use
# - `Date` is not useful information, because all within a few days
# - `Remarks` does not provide additional useful information

# %%
df.drop(['Unnamed: 0', 'Coordinates', 'Date', 'Remarks'],
    axis=1, inplace=True)

# %%
tuple(df.columns.values)
# Out:
# ('Bird Species',
#  'Distance Bin',
#  'Group Name',
#  'Habitat Type',
#  'Location',
#  'Time',
#  'Time Period')

# %%
df.iloc[0]['Location']
# Out:
# '8 Kent Ridge Drive (Just outside Ventus)'

# %%
# identify unique locs by concat group name & loc
lagging_pointer = '{}---{}'.format(
    df.iloc[0]['Group Name'], df.iloc[0]['Location'])
current_pointer = ''
last_time_period = ''

species_counter = {
    'Black-naped oriole': 0,
    'Javan myna': 0,
    'Olive-backed sunbird': 0,
    'Rock pigeon': 0,
    'Yellow-vented bulbul': 0
}

count_per_site_df = pd.DataFrame()

for _, row in df.iterrows():
    current_pointer = '{}---{}'.format(row[2], row[4])
    if current_pointer == lagging_pointer:
        # still on the same site
        species_counter[row[0]] += 1
    else:
        # current_pointer is on a new site
        # first, save the information
        for species, count in species_counter.items():
            count_per_site_df = count_per_site_df.append(
                {
                    'Bird Species': species,
                    'Count': count,
                    'Density': count / (PI * 0.25 ** 2),
                    'Location': lagging_pointer,
                    'Time Period': last_time_period
                }
                , ignore_index=True
            )
        # reset the species_counter...
        species_counter = {
            'Black-naped oriole': 0,
            'Javan myna': 0,
            'Olive-backed sunbird': 0,
            'Rock pigeon': 0,
            'Yellow-vented bulbul': 0
        }
        # then, count current_pointer
        species_counter[row[0]] += 1
    # move lagging_pointer up
    lagging_pointer = current_pointer
    last_time_period = row[6]

# clean up the last site
for species, count in species_counter.items():
    count_per_site_df = count_per_site_df.append(
        {
            'Bird Species': species,
            'Count': count,
            'Density': count / (PI * 0.25 ** 2),
            'Location': lagging_pointer,
            'Time Period': last_time_period
        }, ignore_index=True)

# %%
count_per_site_df
# Out:
#              Bird Species  Count     Density  \
# 0             Rock pigeon    0.0    0.000000
# 1    Olive-backed sunbird    1.0    5.092958
# 2              Javan myna    0.0    0.000000
# 3    Yellow-vented bulbul    0.0    0.000000
# 4      Black-naped oriole    2.0   10.185916
# 5             Rock pigeon    0.0    0.000000
# 6    Olive-backed sunbird    1.0    5.092958
# 7              Javan myna    0.0    0.000000
# 8    Yellow-vented bulbul    0.0    0.000000
# 9      Black-naped oriole    0.0    0.000000
# 10            Rock pigeon    0.0    0.000000
# 11   Olive-backed sunbird    1.0    5.092958
# 12             Javan myna    0.0    0.000000
# 13   Yellow-vented bulbul    3.0   15.278875
# 14     Black-naped oriole    1.0    5.092958
# 15            Rock pigeon   22.0  112.045080
# 16   Olive-backed sunbird    2.0   10.185916
# 17             Javan myna    3.0   15.278875
# 879  Crimson Sunbird---Opposite Shaw Foundation Bui...        1500
# 880  Crimson Sunbird---Along Business Link, near He...        1520
# 881  Crimson Sunbird---Along Business Link, near He...        1520
# 882  Crimson Sunbird---Along Business Link, near He...        1520
# 883  Crimson Sunbird---Along Business Link, near He...        1520
# 884  Crimson Sunbird---Along Business Link, near He...        1520
# 885             Crimson Sunbird---Prince George's Park        1545
# 886             Crimson Sunbird---Prince George's Park        1545
# 887             Crimson Sunbird---Prince George's Park        1545
# 888             Crimson Sunbird---Prince George's Park        1545
# 889             Crimson Sunbird---Prince George's Park        1545
# 890              Spotted Wood Owl---Behind South Tower        0934
# 891              Spotted Wood Owl---Behind South Tower        0934
# 892              Spotted Wood Owl---Behind South Tower        0934
# 893              Spotted Wood Owl---Behind South Tower        0934
# 894              Spotted Wood Owl---Behind South Tower        0934
#
# [895 rows x 5 columns]

# %%
for i, row in df.iterrows():
    df.loc[i, 'Location'] = row[2] + '---' + row[4]

# %%
print('len(count_per_site_df): {}\nlen(df): {}'.format(
    len(count_per_site_df), len(df)))
print('len(set(count_per_site_df[\'Location\'])): {}'.format(
    len(set(count_per_site_df['Location']))))
print('len(set(df[\'Location\'])): {}'.format(
    len(set(df['Location']))))
# Out:
# len(count_per_site_df): 895
# len(df): 999
# len(set(count_per_site_df['Location'])): 179
# len(set(df['Location'])): 179

# %%
empty_sites = 200 - len(set(count_per_site_df['Location']))

for i in range(empty_sites):
    for species in species_counter.keys():
        count_per_site_df = count_per_site_df.append(
            {
                'Bird Species': species,
                'Count': 0,
                'Density': 0,
                'Location': 'empty{}'.format(i+1),
                'Time Period': None
            }, ignore_index=True
        )

# %%
print('len(count_per_site_df): {}\nlen(df): {}'.format(
    len(count_per_site_df), len(df)))
print('len(set(count_per_site_df[\'Location\'])): {}'.format(
    len(set(count_per_site_df['Location']))))
print('len(set(df[\'Location\'])): {}'.format(
    len(set(df['Location']))))
# Out:
# len(count_per_site_df): 1000
# len(df): 999
# len(set(count_per_site_df['Location'])): 200
# len(set(df['Location'])): 179

# %%
count_per_site_df
# Out:
#              Bird Species  Count     Density  \
# 0             Rock pigeon    0.0    0.000000
# 1    Olive-backed sunbird    1.0    5.092958
# 2              Javan myna    0.0    0.000000
# 3    Yellow-vented bulbul    0.0    0.000000
# 4      Black-naped oriole    2.0   10.185916
# 5             Rock pigeon    0.0    0.000000
# 6    Olive-backed sunbird    1.0    5.092958
# 7              Javan myna    0.0    0.000000
# 8    Yellow-vented bulbul    0.0    0.000000
# 9      Black-naped oriole    0.0    0.000000
# 10            Rock pigeon    0.0    0.000000
# 11   Olive-backed sunbird    1.0    5.092958
# 12             Javan myna    0.0    0.000000
# 13   Yellow-vented bulbul    3.0   15.278875
# 14     Black-naped oriole    1.0    5.092958
# 15            Rock pigeon   22.0  112.045080
# 16   Olive-backed sunbird    2.0   10.185916
# 17             Javan myna    3.0   15.278875
# 18   Yellow-vented bulbul    5.0   25.464791
# 19     Black-naped oriole    0.0    0.000000
# 20            Rock pigeon    2.0   10.185916
# 21   Olive-backed sunbird    2.0   10.185916
# 22             Javan myna    7.0   35.650707
# 23   Yellow-vented bulbul    1.0    5.092958
# 24     Black-naped oriole    0.0    0.000000
# 25            Rock pigeon    0.0    0.000000
# 26   Olive-backed sunbird    0.0    0.000000
# 27             Javan myna    0.0    0.000000
# 28   Yellow-vented bulbul    1.0    5.092958
# 29     Black-naped oriole    0.0    0.000000
# ..                    ...    ...         ...
# 970           Rock pigeon    0.0    0.000000
# 971  Olive-backed sunbird    0.0    0.000000
# 972            Javan myna    0.0    0.000000
# 973  Yellow-vented bulbul    0.0    0.000000
# 974    Black-naped oriole    0.0    0.000000
# 975           Rock pigeon    0.0    0.000000
# 976  Olive-backed sunbird    0.0    0.000000
# 977            Javan myna    0.0    0.000000
# 978  Yellow-vented bulbul    0.0    0.000000
# 979    Black-naped oriole    0.0    0.000000
# 980           Rock pigeon    0.0    0.000000
# 981  Olive-backed sunbird    0.0    0.000000
# 982            Javan myna    0.0    0.000000
# 983  Yellow-vented bulbul    0.0    0.000000
# 984    Black-naped oriole    0.0    0.000000
# 985           Rock pigeon    0.0    0.000000
# 986  Olive-backed sunbird    0.0    0.000000
# 987            Javan myna    0.0    0.000000
# 988  Yellow-vented bulbul    0.0    0.000000
# 989    Black-naped oriole    0.0    0.000000
# 990           Rock pigeon    0.0    0.000000
# 991  Olive-backed sunbird    0.0    0.000000
# 992            Javan myna    0.0    0.000000
# 993  Yellow-vented bulbul    0.0    0.000000
# 994    Black-naped oriole    0.0    0.000000
# 995           Rock pigeon    0.0    0.000000
# 996  Olive-backed sunbird    0.0    0.000000
# 997            Javan myna    0.0    0.000000
# 998  Yellow-vented bulbul    0.0    0.000000
# 999    Black-naped oriole    0.0    0.000000
#
#                                               Location Time Period
# 0    Asian Koel---8 Kent Ridge Drive (Just outside ...        0932
# 1    Asian Koel---8 Kent Ridge Drive (Just outside ...        0932
# 2    Asian Koel---8 Kent Ridge Drive (Just outside ...        0932
# 3    Asian Koel---8 Kent Ridge Drive (Just outside ...        0932
# 4    Asian Koel---8 Kent Ridge Drive (Just outside ...        0932
# 5    Asian Koel---11 Arts Link (Outside AS5 facing ...        1005
# 6    Asian Koel---11 Arts Link (Outside AS5 facing ...        1005
# 7    Asian Koel---11 Arts Link (Outside AS5 facing ...        1005
# 8    Asian Koel---11 Arts Link (Outside AS5 facing ...        1005
# 9    Asian Koel---11 Arts Link (Outside AS5 facing ...        1005
# 10   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...        1035
# 11   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...        1035
# 12   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...        1035
# 13   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...        1035
# 14   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...        1035
# 15   Asian Koel---3 Research Link (End of D1 Bus te...        1055
# 16   Asian Koel---3 Research Link (End of D1 Bus te...        1055
# 17   Asian Koel---3 Research Link (End of D1 Bus te...        1055
# 18   Asian Koel---3 Research Link (End of D1 Bus te...        1055
# 19   Asian Koel---3 Research Link (End of D1 Bus te...        1055
# 20   Spotted Dove---NUS Medical Drive near NUS Grad...        0925
# 21   Spotted Dove---NUS Medical Drive near NUS Grad...        0925
# 22   Spotted Dove---NUS Medical Drive near NUS Grad...        0925
# 23   Spotted Dove---NUS Medical Drive near NUS Grad...        0925
# 24   Spotted Dove---NUS Medical Drive near NUS Grad...        0925
# 25                                Spotted Dove---LKCNM        0925
# 26                                Spotted Dove---LKCNM        0925
# 27                                Spotted Dove---LKCNM        0925
# 28                                Spotted Dove---LKCNM        0925
# 29                                Spotted Dove---LKCNM        0925
# ..                                                 ...         ...
# 970                                            empty16        None
# 971                                            empty16        None
# 972                                            empty16        None
# 973                                            empty16        None
# 974                                            empty16        None
# 975                                            empty17        None
# 976                                            empty17        None
# 977                                            empty17        None
# 978                                            empty17        None
# 979                                            empty17        None
# 980                                            empty18        None
# 981                                            empty18        None
# 982                                            empty18        None
# 983                                            empty18        None
# 984                                            empty18        None
# 985                                            empty19        None
# 986                                            empty19        None
# 987                                            empty19        None
# 988                                            empty19        None
# 989                                            empty19        None
# 990                                            empty20        None
# 991                                            empty20        None
# 992                                            empty20        None
# 993                                            empty20        None
# 994                                            empty20        None
# 995                                            empty21        None
# 996                                            empty21        None
# 997                                            empty21        None
# 998                                            empty21        None
# 999                                            empty21        None
#
# [1000 rows x 5 columns]

# %%
count_per_site_df.Count = count_per_site_df.Count.astype(int)

# %%
count_per_site_df.to_csv('counts_per_site.csv')
