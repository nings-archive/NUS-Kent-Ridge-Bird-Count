# %%
import pandas as pd
df = pd.read_csv('data.csv')  # TODO: pd assumes Time/Time Period are ints

# %%
tuple(df.columns.values)
# Out:
# ('Unnamed: 0',
#  'Bird Species',
#  'Coordinates',
#  'Date',
#  'Distance Bin',
#  'Group Name',
#  'Habitat Type',
#  'Location',
#  'Remarks',
#  'Time',
#  'Time Period')

# %% [markdown]
# # Simplify data
# by removing useless columns
# - `Unnamed: 0` is a side effect column from preprocess
# - `Coordinates` is too varied in formatting and accuracy to use
# - `Date` is not useful information, because all within a few days
# - `Remarks` does not provide additional useful information

# %%
df.drop(['Unnamed: 0', 'Coordinates', 'Date', 'Remarks'],
    axis=1, inplace=True)

# %%
tuple(df.columns.values)
# Out:
# ('Bird Species',
#  'Distance Bin',
#  'Group Name',
#  'Habitat Type',
#  'Location',
#  'Time',
#  'Time Period')

# %%
df.iloc[0]['Location']
# Out:
# '8 Kent Ridge Drive (Just outside Ventus)'

# %%
# identify unique locs by concat group name & loc
lagging_pointer = '{}---{}'.format(
    df.iloc[0]['Group Name'], df.iloc[0]['Location'])
current_pointer = ''
last_time_period = ''

species_counter = {
    'Black-naped oriole': 0,
    'Javan myna': 0,
    'Olive-backed sunbird': 0,
    'Rock pigeon': 0,
    'Yellow-vented bulbul': 0
}

count_per_site_df = pd.DataFrame()

for _, row in df.iterrows():
    current_pointer = '{}---{}'.format(row[2], row[4])
    if current_pointer == lagging_pointer:
        # still on the same site
        species_counter[row[0]] += 1
    else:
        # current_pointer is on a new site
        # first, save the information
        for species, count in species_counter.items():
            count_per_site_df = count_per_site_df.append(
                {
                    'Bird Species': species,
                    'Count': count,
                    'Location': lagging_pointer,
                    'Time Period': last_time_period
                }
                , ignore_index=True
            )
        # reset the species_counter...
        species_counter = {
            'Black-naped oriole': 0,
            'Javan myna': 0,
            'Olive-backed sunbird': 0,
            'Rock pigeon': 0,
            'Yellow-vented bulbul': 0
        }
        # then, count current_pointer
        species_counter[row[0]] += 1
    # move lagging_pointer up
    lagging_pointer = current_pointer
    last_time_period = row[6]

# clean up the last site
for species, count in species_counter.items():
            count_per_site_df = count_per_site_df.append(
                {
                    'Bird Species': species,
                    'Count': int(count),
                    'Location': lagging_pointer,
                    'Time Period': last_time_period
                }
                , ignore_index=True
            )
            count = 0

# %%
count_per_site_df
# Out:
#              Bird Species  Count  \
# 0    Yellow-vented bulbul    0.0
# 1              Javan myna    0.0
# 2    Olive-backed sunbird    1.0
# 3      Black-naped oriole    2.0
# 4             Rock pigeon    0.0
# 5    Yellow-vented bulbul    0.0
# 6              Javan myna    0.0
# 7    Olive-backed sunbird    1.0
# 8      Black-naped oriole    0.0
# 9             Rock pigeon    0.0
# 10   Yellow-vented bulbul    3.0
# 11             Javan myna    0.0
# 12   Olive-backed sunbird    1.0
# 13     Black-naped oriole    1.0
# 14            Rock pigeon    0.0
# 15   Yellow-vented bulbul    5.0
# 16             Javan myna    3.0
# 17   Olive-backed sunbird    2.0
# 18     Black-naped oriole    0.0
# 19            Rock pigeon   22.0
# 20   Yellow-vented bulbul    1.0
# 21             Javan myna    7.0
# 22   Olive-backed sunbird    2.0
# 23     Black-naped oriole    0.0
# 24            Rock pigeon    2.0
# 25   Yellow-vented bulbul    1.0
# 26             Javan myna    0.0
# 27   Olive-backed sunbird    0.0
# 28     Black-naped oriole    0.0
# 29            Rock pigeon    0.0
# ..                    ...    ...
# 865  Yellow-vented bulbul    0.0
# 866            Javan myna    1.0
# 867  Olive-backed sunbird    0.0
# 868    Black-naped oriole    0.0
# 869           Rock pigeon    2.0
# 870  Yellow-vented bulbul    3.0
# 871            Javan myna    0.0
# 872  Olive-backed sunbird    0.0
# 873    Black-naped oriole    0.0
# 874           Rock pigeon    1.0
# 875  Yellow-vented bulbul    1.0
# 876            Javan myna    0.0
# 877  Olive-backed sunbird    1.0
# 878    Black-naped oriole    1.0
# 879           Rock pigeon    0.0
# 880  Yellow-vented bulbul    0.0
# 881            Javan myna    1.0
# 882  Olive-backed sunbird    0.0
# 883    Black-naped oriole    0.0
# 884           Rock pigeon    0.0
# 885  Yellow-vented bulbul    0.0
# 886            Javan myna    1.0
# 887  Olive-backed sunbird    0.0
# 888    Black-naped oriole    0.0
# 889           Rock pigeon    0.0
# 890  Yellow-vented bulbul    8.0
# 891            Javan myna    0.0
# 892  Olive-backed sunbird    0.0
# 893    Black-naped oriole    0.0
# 894           Rock pigeon    0.0
#
#                                               Location  Time Period
# 0    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 1    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 2    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 3    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 4    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 5    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 6    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 7    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 8    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 9    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 10   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 11   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 12   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 13   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 14   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 15   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 16   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 17   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 18   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 19   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 20   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 21   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 22   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 23   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 24   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 25                                Spotted Dove---LKCNM        925.0
# 26                                Spotted Dove---LKCNM        925.0
# 27                                Spotted Dove---LKCNM        925.0
# 28                                Spotted Dove---LKCNM        925.0
# 29                                Spotted Dove---LKCNM        925.0
# ..                                                 ...          ...
# 865              Crimson Sunbird---Between S12 and S13       1048.0
# 866              Crimson Sunbird---Between S12 and S13       1048.0
# 867              Crimson Sunbird---Between S12 and S13       1048.0
# 868              Crimson Sunbird---Between S12 and S13       1048.0
# 869              Crimson Sunbird---Between S12 and S13       1048.0
# 870  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 871  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 872  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 873  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 874  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 875  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 876  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 877  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 878  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 879  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 880  Crimson Sunbird---Along Business Link, near He...       1520.0
# 881  Crimson Sunbird---Along Business Link, near He...       1520.0
# 882  Crimson Sunbird---Along Business Link, near He...       1520.0
# 883  Crimson Sunbird---Along Business Link, near He...       1520.0
# 884  Crimson Sunbird---Along Business Link, near He...       1520.0
# 885             Crimson Sunbird---Prince George's Park       1545.0
# 886             Crimson Sunbird---Prince George's Park       1545.0
# 887             Crimson Sunbird---Prince George's Park       1545.0
# 888             Crimson Sunbird---Prince George's Park       1545.0
# 889             Crimson Sunbird---Prince George's Park       1545.0
# 890              Spotted Wood Owl---Behind South Tower        934.0
# 891              Spotted Wood Owl---Behind South Tower        934.0
# 892              Spotted Wood Owl---Behind South Tower        934.0
# 893              Spotted Wood Owl---Behind South Tower        934.0
# 894              Spotted Wood Owl---Behind South Tower        934.0
#
# [895 rows x 4 columns]

# %%
for i, row in df.iterrows():
    df.loc[i, 'Location'] = row[2] + '---' + row[4]

# %%
print('len(count_per_site_df): {}\nlen(df): {}'.format(
    len(count_per_site_df), len(df)))
print('len(set(count_per_site_df[\'Location\'])): {}'.format(
    len(set(count_per_site_df['Location']))))
print('len(set(df[\'Location\'])): {}'.format(
    len(set(df['Location']))))
# Out:
# len(count_per_site_df): 895
# len(df): 999
# len(set(count_per_site_df['Location'])): 179
# len(set(df['Location'])): 179

# %%
count_per_site_df
# Out:
#              Bird Species  Count  \
# 0    Yellow-vented bulbul    0.0
# 1              Javan myna    0.0
# 2    Olive-backed sunbird    1.0
# 3      Black-naped oriole    2.0
# 4             Rock pigeon    0.0
# 5    Yellow-vented bulbul    0.0
# 6              Javan myna    0.0
# 7    Olive-backed sunbird    1.0
# 8      Black-naped oriole    0.0
# 9             Rock pigeon    0.0
# 10   Yellow-vented bulbul    3.0
# 11             Javan myna    0.0
# 12   Olive-backed sunbird    1.0
# 13     Black-naped oriole    1.0
# 14            Rock pigeon    0.0
# 15   Yellow-vented bulbul    5.0
# 16             Javan myna    3.0
# 17   Olive-backed sunbird    2.0
# 18     Black-naped oriole    0.0
# 19            Rock pigeon   22.0
# 20   Yellow-vented bulbul    1.0
# 21             Javan myna    7.0
# 22   Olive-backed sunbird    2.0
# 23     Black-naped oriole    0.0
# 24            Rock pigeon    2.0
# 25   Yellow-vented bulbul    1.0
# 26             Javan myna    0.0
# 27   Olive-backed sunbird    0.0
# 28     Black-naped oriole    0.0
# 29            Rock pigeon    0.0
# ..                    ...    ...
# 865  Yellow-vented bulbul    0.0
# 866            Javan myna    1.0
# 867  Olive-backed sunbird    0.0
# 868    Black-naped oriole    0.0
# 869           Rock pigeon    2.0
# 870  Yellow-vented bulbul    3.0
# 871            Javan myna    0.0
# 872  Olive-backed sunbird    0.0
# 873    Black-naped oriole    0.0
# 874           Rock pigeon    1.0
# 875  Yellow-vented bulbul    1.0
# 876            Javan myna    0.0
# 877  Olive-backed sunbird    1.0
# 878    Black-naped oriole    1.0
# 879           Rock pigeon    0.0
# 880  Yellow-vented bulbul    0.0
# 881            Javan myna    1.0
# 882  Olive-backed sunbird    0.0
# 883    Black-naped oriole    0.0
# 884           Rock pigeon    0.0
# 885  Yellow-vented bulbul    0.0
# 886            Javan myna    1.0
# 887  Olive-backed sunbird    0.0
# 888    Black-naped oriole    0.0
# 889           Rock pigeon    0.0
# 890  Yellow-vented bulbul    8.0
# 891            Javan myna    0.0
# 892  Olive-backed sunbird    0.0
# 893    Black-naped oriole    0.0
# 894           Rock pigeon    0.0
#
#                                               Location  Time Period
# 0    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 1    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 2    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 3    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 4    Asian Koel---8 Kent Ridge Drive (Just outside ...        932.0
# 5    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 6    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 7    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 8    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 9    Asian Koel---11 Arts Link (Outside AS5 facing ...       1005.0
# 10   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 11   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 12   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 13   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 14   Asian Koel---15 Kent Ridge Drive (Opp Hon Sui ...       1035.0
# 15   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 16   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 17   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 18   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 19   Asian Koel---3 Research Link (End of D1 Bus te...       1055.0
# 20   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 21   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 22   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 23   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 24   Spotted Dove---NUS Medical Drive near NUS Grad...        925.0
# 25                                Spotted Dove---LKCNM        925.0
# 26                                Spotted Dove---LKCNM        925.0
# 27                                Spotted Dove---LKCNM        925.0
# 28                                Spotted Dove---LKCNM        925.0
# 29                                Spotted Dove---LKCNM        925.0
# ..                                                 ...          ...
# 865              Crimson Sunbird---Between S12 and S13       1048.0
# 866              Crimson Sunbird---Between S12 and S13       1048.0
# 867              Crimson Sunbird---Between S12 and S13       1048.0
# 868              Crimson Sunbird---Between S12 and S13       1048.0
# 869              Crimson Sunbird---Between S12 and S13       1048.0
# 870  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 871  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 872  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 873  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 874  Crimson Sunbird---Behind opposite Kent Ridge M...       1121.0
# 875  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 876  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 877  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 878  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 879  Crimson Sunbird---Opposite Shaw Foundation Bui...       1500.0
# 880  Crimson Sunbird---Along Business Link, near He...       1520.0
# 881  Crimson Sunbird---Along Business Link, near He...       1520.0
# 882  Crimson Sunbird---Along Business Link, near He...       1520.0
# 883  Crimson Sunbird---Along Business Link, near He...       1520.0
# 884  Crimson Sunbird---Along Business Link, near He...       1520.0
# 885             Crimson Sunbird---Prince George's Park       1545.0
# 886             Crimson Sunbird---Prince George's Park       1545.0
# 887             Crimson Sunbird---Prince George's Park       1545.0
# 888             Crimson Sunbird---Prince George's Park       1545.0
# 889             Crimson Sunbird---Prince George's Park       1545.0
# 890              Spotted Wood Owl---Behind South Tower        934.0
# 891              Spotted Wood Owl---Behind South Tower        934.0
# 892              Spotted Wood Owl---Behind South Tower        934.0
# 893              Spotted Wood Owl---Behind South Tower        934.0
# 894              Spotted Wood Owl---Behind South Tower        934.0
#
# [895 rows x 4 columns]

# %%
count_per_site_df.to_csv('count_per_site.csv')
